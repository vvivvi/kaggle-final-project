# %% [raw]
# After having selected sfs lists of 9, 16 and 25 features from feature subsets 'basic','basicv2','allfeat','text' and 'within',
# perform validation experiment and search best hyperparameters for catboost

# %%
# sfs results

feature_lists_sel9={
      "text": [
        "shop_id",
        "target_category_tfidf_unigram_256_lag_6",
        "item_name_cyrillic_fraction",
        "target_category_frequent_256_within_shop_lag_6",
        "target_category_tfidf_bigram_256_within_shop_lag_12",
        "item_name_category_frequent_256",
        "item_name_category_tfidf_bigram_256",
        "item_category_id",
        "target_category_tfidf_unigram_256_lag_5"
      ],
      "within": [
        "target_category_frequent_256_within_shop_lag_12",
        "shop_id",
        "target_category_tfidf_unigram_256_within_shop_lag_4",
        "target_category_tfidf_bigram_256_within_shop_lag_5",
        "target_category_tfidf_bigram_256_within_shop_lag_12",
        "target_category_within_shop_lag_2",
        "target_category_tfidf_bigram_256_within_shop_lag_2",
        "item_category_id",
        "target_category_frequent_256_within_shop_lag_2"
      ],
      "allfeat": [
        "target_item_lag_6",
        "target_shop_lag_12",
        "target_item_lag_2",
        "target_lag_2",
        "target_category_tfidf_unigram_256_lag_6",
        "target_item_lag_12",
        "target_category_within_shop_lag_12",
        "target_item_lag_4",
        "item_category_id"
      ],
      "basic": [
        "target_item_lag_6",
        "target_category_lag_5",
        "target_shop_lag_12",
        "target_lag_5",
        "item_category_id",
        "item_id",
        "target_item_lag_3",
        "target_lag_2",
        "time_of_year"
      ],
      "basicv2": [
        "target_category_within_shop_lag_3",
        "target_item_lag_4",
        "target_item_lag_12",
        "target_shop_lag_12",
        "target_shop_lag_4",
        "target_item_lag_2",
        "item_category_id",
        "target_item_lag_3",
        "target_lag_2"
      ]} 

feature_lists_sel16={
      "text": [
        'target_category_tfidf_unigram_256_within_shop_lag_5',
         'shop_id',
         'target_category_frequent_256_lag_6',
         'target_category_tfidf_unigram_256_lag_6',
         'item_name_cyrillic_fraction',
         'target_category_tfidf_bigram_256_lag_2',
         'target_category_frequent_256_within_shop_lag_6',
         'target_category_tfidf_bigram_256_within_shop_lag_12',
         'target_category_tfidf_unigram_256_within_shop_lag_3',
         'target_category_tfidf_bigram_256_lag_12',
         'item_name_category_frequent_256',
         'item_name_category_tfidf_bigram_256',
         'item_category_id',
         'target_category_tfidf_unigram_256_lag_5',
         'target_category_tfidf_unigram_256_within_shop_lag_12',
         'target_category_tfidf_bigram_256_within_shop_lag_6'
      ],
      "within": [
         'target_category_frequent_256_within_shop_lag_12',
         'target_category_within_shop_lag_5',
         'shop_id',
         'target_category_within_shop_lag_3',
         'target_category_tfidf_unigram_256_within_shop_lag_4',
         'target_category_tfidf_bigram_256_within_shop_lag_5',
         'target_category_within_shop_lag_4',
         'target_category_tfidf_bigram_256_within_shop_lag_12',
         'target_category_tfidf_unigram_256_within_shop_lag_3',
         'target_category_within_shop_lag_2',
         'target_category_tfidf_bigram_256_within_shop_lag_2',
         'item_category_id',
         'item_id',
         'target_category_frequent_256_within_shop_lag_2',
         'target_category_tfidf_unigram_256_within_shop_lag_12',
         'target_category_tfidf_bigram_256_within_shop_lag_6'
      ],
      "allfeat": [
         'target_category_tfidf_unigram_256_within_shop_lag_4',
         'target_item_lag_6',
         'target_category_lag_5',
         'target_category_tfidf_unigram_256_lag_5',
         'item_name_cyrillic_fraction',
         'target_shop_lag_12',
         'target_item_lag_2',
         'target_lag_2',
         'target_category_within_shop_lag_3',
         'target_category_tfidf_unigram_256_lag_6',
         'target_item_lag_12',
         'target_category_tfidf_unigram_256_within_shop_lag_5',
         'target_category_within_shop_lag_12',
         'target_item_lag_4',
         'item_category_id',
         'target_category_within_shop_lag_2'
      ],
      "basic": [
         'shop_id',
         'target_lag_6',
         'target_item_lag_6',
         'target_item_lag_12',
         'target_category_lag_5',
         'target_shop_lag_12',
         'item_name_category_tfidf_bigram_256',
         'target_lag_5',
         'target_category_lag_2',
         'target_item_lag_2',
         'item_category_id',
         'item_id',
         'target_item_lag_3',
         'target_lag_2',
         'target_item_lag_5',
         'time_of_year'
      ],
      "basicv2": [
         'target_category_tfidf_unigram_256_within_shop_lag_5',
         'target_category_tfidf_bigram_256_within_shop_lag_6',
         'target_category_within_shop_lag_3',
         'target_item_lag_4',
         'item_name_cyrillic_fraction',
         'target_item_lag_12',
         'target_lag_3',
         'target_shop_lag_12',
         'target_shop_lag_4',
         'target_lag_5',
         'target_item_lag_2',
         'item_category_id',
         'target_category_tfidf_bigram_256_within_shop_lag_2',
         'item_id',
         'target_item_lag_3',
         'target_lag_2'
      ]}

feature_lists_sel25={
      "text": [
         'target_category_tfidf_bigram_256_lag_5',
         'target_category_tfidf_unigram_256_within_shop_lag_5',
         'shop_id',
         'target_category_frequent_256_lag_6',
         'target_category_tfidf_bigram_256_within_shop_lag_4',
         'date_block_num',
         'target_category_tfidf_unigram_256_lag_6',
         'item_name_cyrillic_fraction',
         'target_category_tfidf_bigram_256_lag_2',
         'item_name_category_tfidf_unigram_256',
         'target_category_tfidf_unigram_256_within_shop_lag_6',
         'target_category_frequent_256_within_shop_lag_6',
         'target_category_tfidf_bigram_256_within_shop_lag_12',
         'target_category_tfidf_unigram_256_within_shop_lag_3',
         'target_category_tfidf_bigram_256_lag_12',
         'item_name_category_frequent_256',
         'item_name_category_tfidf_bigram_256',
         'target_category_tfidf_bigram_256_within_shop_lag_2',
         'item_category_id',
         'item_id',
         'target_category_tfidf_unigram_256_lag_5',
         'target_category_tfidf_bigram_256_lag_3',
         'target_category_tfidf_unigram_256_within_shop_lag_12',
         'target_category_tfidf_bigram_256_within_shop_lag_6',
         'time_of_year'
      ],
      "within": [
         'target_category_frequent_256_within_shop_lag_12',
         'target_category_tfidf_unigram_256_within_shop_lag_5',
         'target_category_within_shop_lag_5',
         'shop_id',
         'target_category_tfidf_bigram_256_within_shop_lag_4',
         'target_category_within_shop_lag_12',
         'date_block_num',
         'target_category_within_shop_lag_3',
         'target_category_frequent_256_within_shop_lag_5',
         'target_category_tfidf_unigram_256_within_shop_lag_4',
         'target_category_tfidf_bigram_256_within_shop_lag_5',
         'target_category_within_shop_lag_4',
         'target_category_frequent_256_within_shop_lag_6',
         'target_category_tfidf_bigram_256_within_shop_lag_3',
         'target_category_tfidf_bigram_256_within_shop_lag_12',
         'target_category_tfidf_unigram_256_within_shop_lag_3',
         'target_category_within_shop_lag_2',
         'target_category_tfidf_bigram_256_within_shop_lag_2',
         'item_category_id',
         'item_id',
         'target_category_frequent_256_within_shop_lag_4',
         'target_category_frequent_256_within_shop_lag_2',
         'target_category_tfidf_unigram_256_within_shop_lag_12',
         'target_category_tfidf_bigram_256_within_shop_lag_6',
         'time_of_year' 
      ],
      "allfeat": [
         'target_category_tfidf_unigram_256_within_shop_lag_4',
         'target_item_lag_6',
         'target_category_lag_5',
         'target_category_frequent_256_within_shop_lag_6',
         'target_category_within_shop_lag_6',
         'target_category_tfidf_unigram_256_lag_12',
         'target_category_lag_2',
         'target_category_tfidf_unigram_256_lag_5',
         'target_category_frequent_256_within_shop_lag_2',
         'target_category_tfidf_bigram_256_within_shop_lag_6',
         'item_name_cyrillic_fraction',
         'target_shop_lag_12',
         'target_item_lag_2',
         'target_lag_2',
         'shop_id',
         'target_category_within_shop_lag_3',
         'target_category_tfidf_unigram_256_lag_6',
         'target_item_lag_12',
         'target_item_lag_3',
         'target_category_tfidf_unigram_256_within_shop_lag_5',
         'target_category_frequent_256_lag_6',
         'target_category_within_shop_lag_12',
         'target_item_lag_4',
         'item_category_id',
         'target_category_within_shop_lag_2'
      ],
      "basic": [
         'shop_id',
         'target_lag_6',
         'is_internet_store',
         'item_name_cyrillic_fraction',
         'target_item_lag_6',
         'target_category_lag_3',
         'item_name_category_tfidf_unigram_256',
         'target_item_lag_12',
         'target_category_lag_5',
         'item_name_category_frequent_256',
         'target_category_lag_4',
         'target_shop_lag_12',
         'item_name_category_tfidf_bigram_256',
         'target_lag_5',
         'target_category_lag_2',
         'target_item_lag_2',
         'target_shop_lag_3',
         'item_category_id',
         'item_id',
         'target_lag_4',
         'target_shop_lag_6',
         'target_item_lag_3',
         'target_lag_2',
         'target_item_lag_5',
         'time_of_year'
      ],
      "basicv2": [
         'target_category_tfidf_unigram_256_within_shop_lag_5',
         'target_category_tfidf_bigram_256_within_shop_lag_6',
         'target_category_lag_12',
         'target_category_within_shop_lag_5',
         'shop_id',
         'is_internet_store',
         'target_category_within_shop_lag_3',
         'target_item_lag_4',
         'item_name_cyrillic_fraction',
         'target_item_lag_6',
         'target_item_lag_12',
         'target_category_lag_5',
         'item_name_category_frequent_256',
         'target_lag_3',
         'target_shop_lag_12',
         'target_shop_lag_4',
         'target_lag_5',
         'target_category_lag_2',
         'target_item_lag_2',
         'item_category_id',
         'target_category_tfidf_bigram_256_within_shop_lag_2',
         'item_id',
         'target_lag_4',
         'target_item_lag_3',
         'target_lag_2'
      ]}

# %%
import sys
import os.path
import json
import numpy as np
import pandas as pd 
import sklearn
import scipy.sparse 
from itertools import product
import gc
from tqdm import tqdm_notebook
import re
from catboost import CatBoostRegressor, Pool

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab import drive
  drive.mount('/content/gdrive') 
  if not os.path.isfile('SETTINGS.json'):
       # hard coded data directory in drive is used if SETTINGS.json not present 
       config={}
       config['DATA_DIR'] = '/content/gdrive/My Drive/kaggle-c1'
       with open('SETTINGS.json', 'w') as outfile:
         json.dump(config, outfile)

with open('SETTINGS.json') as config_file:
    config = json.load(config_file)

DATA_DIR = config['DATA_DIR']

print('Using DATA_DIR ', DATA_DIR)

DATA_FOLDER = DATA_DIR
# Out:
# Using DATA_DIR  /home/vvi/repos/coursera/HSE/kaggle-c1/competitive-data-science-predict-future-sales

# %%
test_spec = pd.read_csv(os.path.join(DATA_FOLDER, 'test.csv'))

index_cols=['item_id','shop_id','date_block_num']
#date_block_val = 33
date_block_val = 23 # Dec 2014
date_block_test = 35 # Dec 2015

# %%
# a wrapper class to use pre-defined division to training and hold-out set
# as a cross-validation object

class HoldOut:
    """
    Hold-out cross-validator generator. In the hold-out, the
    data is split only once into a train set and a test set.
    Here the split is given as a input parameter in the class initialisation
    Unlike in other cross-validation schemes, the hold-out
    consists of only one iteration.

    Parameters
    ----------
    train_indices, test_indices : the class just passes on these when yielding splits


    """

    def __init__(self, train_indices, test_indices):
        self.train_indices = train_indices
        self.test_indices = test_indices

    def __iter__(self):
        yield self.train_indices, self.test_indices

# %%
def downcast_dtypes(df):
    '''
        Changes column types in the dataframe: 
                
                `float64` type to `float32`
                `int64`   type to `int32`
    '''
    
    # Select columns to downcast
    float_cols = [c for c in df if df[c].dtype == "float64"]
    int_cols =   [c for c in df if df[c].dtype == "int64"]
    
    # Downcast
    df[float_cols] = df[float_cols].astype(np.float32)
    df[int_cols]   = df[int_cols].astype(np.int32)
    
    return df

# %%
def write_predictions_by_array(array, filename):
  df=pd.DataFrame(np.clip(array,0,20))
  df.columns=['item_cnt_month']
  df.to_csv(os.path.join(DATA_FOLDER, filename), index_label='ID')

# %%
def clipped_rmse(gt, predicted,clip_min=0, clip_max=20):
  target=np.minimum(np.maximum(gt,clip_min), clip_max)
  return np.sqrt((target-predicted)**2).mean()

# %%
def average_submissions(filenames_in, id_out):
    df_first = pd.read_csv(os.path.join(DATA_FOLDER, filenames_in[0]))
    n_rows = df_first.shape[0]                       
    result = np.zeros((n_rows,1))
    for fn in filenames_in:
      df = pd.read_csv(os.path.join(DATA_FOLDER, fn))
      contrib = df['item_cnt_month'].to_numpy()/len(filenames_in)              
      print(contrib.shape)  
      result += contrib[...,np.newaxis]  
    fn_out = 'submission-average-{}.csv'.format(id_out)
    write_predictions_by_array(result, fn_out)

# %%
import itertools

def iterate_parameter_combinations(options):
    keys = options.keys()
    values = (options[key] for key in keys)
    return [dict(zip(keys, combination)) for combination in itertools.product(*values)]

# %%
def load_feauture_set(id_string):
  filename=os.path.join(DATA_FOLDER, 'feature_set_{}.csv').format(id_string)
  print('reading from file {}'.format(filename))
  all_data = pd.read_csv(os.path.join(DATA_FOLDER, filename))

  all_data['target']=np.clip(all_data['target'],0,20)
  all_data['time_of_year'] = (all_data['date_block_num']+6) % 12   

  dates=all_data['date_block_num']

  #dates_train = (dates>= date_block_val - 13) & (dates<= date_block_val - 2)
  #dates_trainval = (dates>= date_block_test - 13) & (dates<= date_block_test - 2)
    
  dates_train =  (dates<= date_block_val - 2)
  dates_trainval = (dates<= date_block_test - 2)
  

# extract training, validation and test sets (labels and features)

  y_train=all_data.loc[dates_train, 'target'] 
  y_trainval=all_data.loc[dates_trainval, 'target']
  y_val = all_data.loc[dates == date_block_val, 'target']

  # to_drop_cols = ['target','date_block_num']+[col for col in all_data.columns.values if re.search('item_price',col)]
  # to_drop_cols = ['target']+[col for col in all_data.columns.values if re.search('item_price',col)]
  to_drop_cols = ['target']
    

  X_train = all_data.loc[dates_train].drop(to_drop_cols, axis=1)
  X_trainval = all_data.loc[dates_trainval].drop(to_drop_cols, axis=1)
  X_val = all_data.loc[dates == date_block_val].drop(to_drop_cols, axis=1)
  X_test = all_data.loc[dates == date_block_test].drop(to_drop_cols, axis=1)

# determine how to permute test set predictions for submission generation 
  shop_item2submissionid={} 
  for idx, row in test_spec.iterrows():
    shop_item2submissionid[str(row['shop_id'])+'_'+str(row['item_id'])] = row['ID']
    
  test_data=all_data.loc[dates == date_block_test, ['shop_id','item_id']]    
    
  testidx2submissionidx=np.zeros(test_data.shape[0], dtype=np.int32)
  for idx in range(test_data.shape[0]):
    row =test_data.iloc[idx]
    testidx2submissionidx[idx] = shop_item2submissionid[str(row['shop_id'])+'_'+str(row['item_id'])]
 
#invert the mapping
  submissionidx2testidx=np.zeros(test_data.shape[0], dtype=np.int32)
  for i in range(test_data.shape[0]):
    submissionidx2testidx[testidx2submissionidx[i]]=i

  del test_data
  gc.collect()    

  return X_train, y_train, X_trainval, y_trainval, X_val, y_val, X_test, submissionidx2testidx

# %%
grid = {'learning_rate': [0.03, 0.1,0.3,0.5],
        'iterations': [100,300,1000],
        'depth': [10,12,14,15,16],
        'l2_leaf_reg': [0.3, 1, 3, 10],
          'task_type': ['GPU']}

best_params={}          

X_train, y_train, X_trainval, y_trainval, X_val, y_val, X_test, submissionidx2testidx = load_feauture_set('allfeat')

for id in ['basic','basicv2','allfeat','text','within']:
  for numsel in [9,16,25]:  
      comb_list=iterate_parameter_combinations(grid)
      score_list=[]
      selfeat_dict=eval('feature_lists_sel{}'.format(numsel)) 
      for param in comb_list:
        print('Feature set {}_sel{} combination {}/{}'.format(id,numsel,len(score_list)+1,len(comb_list))) 
        print('keeping cols ', selfeat_dict[id])
        to_drop_cols= [col for col in X_train.columns.values if not col in selfeat_dict[id]]
        reg=CatBoostRegressor(metric_period=100, **param)
        reg.fit(X_train.drop(to_drop_cols,axis=1).to_numpy(), y_train)
        pred_val = np.clip(reg.predict(X_val.drop(to_drop_cols,axis=1).to_numpy()), 0, 20)
        rmse = clipped_rmse(y_val, pred_val)
        print('Feature set {} params {} Clipped RMSE {}'.format(id,param,rmse))
        score_list.append(rmse)
        
      print('** Best params for feature set {}_{}: {}'.format(id,numsel,comb_list[np.argmin(score_list)]))      
      best_params['{}_sel{}'.format(id,numsel)]=comb_list[np.argmin(score_list)]
      with open(os.path.join(DATA_FOLDER,'best_params_sfs.json'), 'w') as fp:
        json.dump(best_params, fp)

# %%
with open(os.path.join(DATA_FOLDER,'best_params_sfs.json'), 'w') as fp:
    print(json.load(fp))

# %%
best_params

# %% [raw]
# best params found:
#
# {'basic_sel9': {'learning_rate': 0.5,
#   'iterations': 100,
#   'depth': 14,
#   'l2_leaf_reg': 1,
#   'task_type': 'GPU'},
#  'basic_sel16': {'learning_rate': 0.3,
#   'iterations': 100,
#   'depth': 14,
#   'l2_leaf_reg': 1,
#   'task_type': 'GPU'},
#  'basic_sel25': {'learning_rate': 0.3,
#   'iterations': 100,
#   'depth': 12,
#   'l2_leaf_reg': 3,
#   'task_type': 'GPU'},
#  'basicv2_sel9': {'learning_rate': 0.3,
#   'iterations': 1000,
#   'depth': 14,
#   'l2_leaf_reg': 10,
#   'task_type': 'GPU'},
#  'basicv2_sel16': {'learning_rate': 0.1,
#   'iterations': 300,
#   'depth': 16,
#   'l2_leaf_reg': 10,
#   'task_type': 'GPU'},
#  'basicv2_sel25': {'learning_rate': 0.1,
#   'iterations': 1000,
#   'depth': 10,
#   'l2_leaf_reg': 1,
#   'task_type': 'GPU'},
#  'allfeat_sel9': {'learning_rate': 0.3,
#   'iterations': 100,
#   'depth': 16,
#   'l2_leaf_reg': 0.3,
#   'task_type': 'GPU'},
#  'allfeat_sel16': {'learning_rate': 0.1,
#   'iterations': 1000,
#   'depth': 12,
#   'l2_leaf_reg': 10,
#   'task_type': 'GPU'},
#  'allfeat_sel25': {'learning_rate': 0.1,
#   'iterations': 300,
#   'depth': 15,
#   'l2_leaf_reg': 10,
#   'task_type': 'GPU'},
#  'text_sel9': {'learning_rate': 0.5,
#   'iterations': 300,
#   'depth': 16,
#   'l2_leaf_reg': 1,
#   'task_type': 'GPU'},
#  'text_sel16': {'learning_rate': 0.3,
#   'iterations': 1000,
#   'depth': 16,
#   'l2_leaf_reg': 0.3,
#   'task_type': 'GPU'},
#  'text_sel25': {'learning_rate': 0.3,
#   'iterations': 1000,
#   'depth': 12,
#   'l2_leaf_reg': 3,
#   'task_type': 'GPU'},
#  'within_sel9': {'learning_rate': 0.3,
#   'iterations': 300,
#   'depth': 10,
#   'l2_leaf_reg': 3,
#   'task_type': 'GPU'},
#  'within_sel16': {'learning_rate': 0.3,
#   'iterations': 300,
#   'depth': 14,
#   'l2_leaf_reg': 10,
#   'task_type': 'GPU'},
#  'within_sel25': {'learning_rate': 0.3,
#   'iterations': 1000,
#   'depth': 12,
#   'l2_leaf_reg': 3,
#   'task_type': 'GPU'}}

# %%
best_params= {'basic_sel9': {'learning_rate': 0.5,
  'iterations': 100,
  'depth': 14,
  'l2_leaf_reg': 1,
  'task_type': 'GPU'},
 'basic_sel16': {'learning_rate': 0.3,
  'iterations': 100,
  'depth': 14,
  'l2_leaf_reg': 1,
  'task_type': 'GPU'},
 'basic_sel25': {'learning_rate': 0.3,
  'iterations': 100,
  'depth': 12,
  'l2_leaf_reg': 3,
  'task_type': 'GPU'},
 'basicv2_sel9': {'learning_rate': 0.3,
  'iterations': 1000,
  'depth': 14,
  'l2_leaf_reg': 10,
  'task_type': 'GPU'},
 'basicv2_sel16': {'learning_rate': 0.1,
  'iterations': 300,
  'depth': 16,
  'l2_leaf_reg': 10,
  'task_type': 'GPU'},
 'basicv2_sel25': {'learning_rate': 0.1,
  'iterations': 1000,
  'depth': 10,
  'l2_leaf_reg': 1,
  'task_type': 'GPU'},
 'allfeat_sel9': {'learning_rate': 0.3,
  'iterations': 100,
  'depth': 16,
  'l2_leaf_reg': 0.3,
  'task_type': 'GPU'},
 'allfeat_sel16': {'learning_rate': 0.1,
  'iterations': 1000,
  'depth': 12,
  'l2_leaf_reg': 10,
  'task_type': 'GPU'},
 'allfeat_sel25': {'learning_rate': 0.1,
  'iterations': 300,
  'depth': 15,
  'l2_leaf_reg': 10,
  'task_type': 'GPU'},
 'text_sel9': {'learning_rate': 0.5,
  'iterations': 300,
  'depth': 16,
  'l2_leaf_reg': 1,
  'task_type': 'GPU'},
 'text_sel16': {'learning_rate': 0.3,
  'iterations': 1000,
  'depth': 16,
  'l2_leaf_reg': 0.3,
  'task_type': 'GPU'},
 'text_sel25': {'learning_rate': 0.3,
  'iterations': 1000,
  'depth': 12,
  'l2_leaf_reg': 3,
  'task_type': 'GPU'},
 'within_sel9': {'learning_rate': 0.3,
  'iterations': 300,
  'depth': 10,
  'l2_leaf_reg': 3,
  'task_type': 'GPU'},
 'within_sel16': {'learning_rate': 0.3,
  'iterations': 300,
  'depth': 14,
  'l2_leaf_reg': 10,
  'task_type': 'GPU'},
 'within_sel25': {'learning_rate': 0.3,
  'iterations': 1000,
  'depth': 12,
  'l2_leaf_reg': 3,
  'task_type': 'GPU'}}

# %%
# out of interest, generate submission using the newly found parameters
X_train, y_train, X_trainval, y_trainval, X_val, y_val, X_test, submissionidx2testidx = load_feauture_set('allfeat')

for id in ['basic','basicv2','allfeat','text','within']:
  for numsel in [9,16,25]:  
      print('{}_sel{}'.format(id,numsel))
      selfeat_dict=eval('feature_lists_sel{}'.format(numsel)) 
      print('keeping cols ', selfeat_dict[id])
      to_drop_cols= [col for col in X_train.columns.values if not col in selfeat_dict[id]]
      reg=CatBoostRegressor(**best_params['{}_sel{}'.format(id,numsel)])
      reg.fit(X_trainval.drop(to_drop_cols,axis=1).to_numpy(), y_trainval)
      pred_test = np.clip(reg.predict(X_test.drop(to_drop_cols,axis=1).to_numpy()), 0, 20)
      output_name = 'submission-catboost-bestparams-features_{}_combination_{}.csv'.format(id,'sel{}'.format(numsel))
      write_predictions_by_array(pred_test[submissionidx2testidx], output_name)
# Out:
# reading from file /home/vvi/repos/coursera/HSE/kaggle-c1/competitive-data-science-predict-future-sales/feature_set_allfeat.csv
# basic_sel9
# keeping cols  ['target_item_lag_6', 'target_category_lag_5', 'target_shop_lag_12', 'target_lag_5', 'item_category_id', 'item_id', 'target_item_lag_3', 'target_lag_2', 'time_of_year']
# 0:	learn: 1.0526862	total: 198ms	remaining: 19.6s
# 1:	learn: 1.0526860	total: 233ms	remaining: 11.4s
# 2:	learn: 1.0015140	total: 411ms	remaining: 13.3s
# 3:	learn: 1.0015121	total: 446ms	remaining: 10.7s
# 4:	learn: 0.9763788	total: 626ms	remaining: 11.9s
# 98:	learn: 0.9054313	total: 10.4s	remaining: 105ms
# 99:	learn: 0.9054313	total: 10.4s	remaining: 0us
# basic_sel16
# keeping cols  ['shop_id', 'target_lag_6', 'target_item_lag_6', 'target_item_lag_12', 'target_category_lag_5', 'target_shop_lag_12', 'item_name_category_tfidf_bigram_256', 'target_lag_5', 'target_category_lag_2', 'target_item_lag_2', 'item_category_id', 'item_id', 'target_item_lag_3', 'target_lag_2', 'target_item_lag_5', 'time_of_year']
# 0:	learn: 1.1003837	total: 196ms	remaining: 19.4s
# 1:	learn: 1.1002916	total: 237ms	remaining: 11.6s
# 2:	learn: 1.0464295	total: 440ms	remaining: 14.2s
# 3:	learn: 1.0464042	total: 477ms	remaining: 11.5s
# 4:	learn: 1.0090885	total: 669ms	remaining: 12.7s
# 5:	learn: 1.0090829	total: 708ms	remaining: 11.1s
# 6:	learn: 0.9853396	total: 901ms	remaining: 12s
# 7:	learn: 0.9853384	total: 940ms	remaining: 10.8s
# 8:	learn: 0.9647701	total: 1.14s	remaining: 11.5s
# 9:	learn: 0.9647707	total: 1.18s	remaining: 10.6s
# 10:	learn: 0.9537065	total: 1.38s	remaining: 11.2s
# 11:	learn: 0.9537063	total: 1.42s	remaining: 10.4s
# 12:	learn: 0.9436525	total: 1.61s	remaining: 10.8s
# 13:	learn: 0.9436522	total: 1.65s	remaining: 10.1s
# 14:	learn: 0.9360091	total: 1.85s	remaining: 10.5s
# 15:	learn: 0.9360085	total: 1.89s	remaining: 9.92s
# 16:	learn: 0.9271624	total: 2.08s	remaining: 10.2s
# 17:	learn: 0.9271618	total: 2.12s	remaining: 9.67s
# 18:	learn: 0.9230642	total: 2.32s	remaining: 9.88s
# 19:	learn: 0.9230632	total: 2.36s	remaining: 9.43s
# 20:	learn: 0.9181578	total: 2.56s	remaining: 9.64s
# 21:	learn: 0.9181564	total: 2.6s	remaining: 9.22s
# 22:	learn: 0.9140776	total: 2.8s	remaining: 9.39s
# 23:	learn: 0.9140769	total: 2.84s	remaining: 9s
# 24:	learn: 0.9081718	total: 3.04s	remaining: 9.12s
# 25:	learn: 0.9081706	total: 3.08s	remaining: 8.77s
# 26:	learn: 0.9057811	total: 3.28s	remaining: 8.86s
# 27:	learn: 0.9057024	total: 3.34s	remaining: 8.6s
# 28:	learn: 0.9023836	total: 3.53s	remaining: 8.65s
# 29:	learn: 0.9023820	total: 3.57s	remaining: 8.33s
# 30:	learn: 0.9004966	total: 3.76s	remaining: 8.37s
# 31:	learn: 0.9004960	total: 3.8s	remaining: 8.07s
# 32:	learn: 0.8964729	total: 3.99s	remaining: 8.11s
# 33:	learn: 0.8964720	total: 4.03s	remaining: 7.83s
# 34:	learn: 0.8943426	total: 4.22s	remaining: 7.84s
# 35:	learn: 0.8943420	total: 4.26s	remaining: 7.58s
# 36:	learn: 0.8917229	total: 4.46s	remaining: 7.59s
# 37:	learn: 0.8917224	total: 4.5s	remaining: 7.34s
# 38:	learn: 0.8891996	total: 4.69s	remaining: 7.33s
# 85:	learn: 0.8569026	total: 10s	remaining: 1.63s
# 86:	learn: 0.8565534	total: 10.2s	remaining: 1.52s
# 87:	learn: 0.8565534	total: 10.2s	remaining: 1.4s
# 88:	learn: 0.8561518	total: 10.4s	remaining: 1.29s
# 89:	learn: 0.8561518	total: 10.5s	remaining: 1.16s
# 90:	learn: 0.8553026	total: 10.7s	remaining: 1.05s
# 91:	learn: 0.8553026	total: 10.7s	remaining: 930ms
# 92:	learn: 0.8540559	total: 10.9s	remaining: 819ms
# 93:	learn: 0.8540559	total: 10.9s	remaining: 697ms
# 94:	learn: 0.8533031	total: 11.1s	remaining: 585ms
# 95:	learn: 0.8533032	total: 11.2s	remaining: 465ms
# 96:	learn: 0.8527242	total: 11.3s	remaining: 351ms
# 97:	learn: 0.8524946	total: 11.5s	remaining: 235ms
# 98:	learn: 0.8518726	total: 11.7s	remaining: 118ms
# 99:	learn: 0.8518724	total: 11.7s	remaining: 0us
# basic_sel25
# keeping cols  ['shop_id', 'target_lag_6', 'is_internet_store', 'item_name_cyrillic_fraction', 'target_item_lag_6', 'target_category_lag_3', 'item_name_category_tfidf_unigram_256', 'target_item_lag_12', 'target_category_lag_5', 'item_name_category_frequent_256', 'target_category_lag_4', 'target_shop_lag_12', 'item_name_category_tfidf_bigram_256', 'target_lag_5', 'target_category_lag_2', 'target_item_lag_2', 'target_shop_lag_3', 'item_category_id', 'item_id', 'target_lag_4', 'target_shop_lag_6', 'target_item_lag_3', 'target_lag_2', 'target_item_lag_5', 'time_of_year']
# 0:	learn: 1.1078679	total: 152ms	remaining: 15s
# 1:	learn: 1.0605259	total: 270ms	remaining: 13.2s
# 2:	learn: 1.0329307	total: 400ms	remaining: 12.9s
# 3:	learn: 1.0316524	total: 437ms	remaining: 10.5s
# 4:	learn: 1.0045208	total: 593ms	remaining: 11.3s
# 5:	learn: 0.9910852	total: 727ms	remaining: 11.4s
# 6:	learn: 0.9757008	total: 874ms	remaining: 11.6s
# 7:	learn: 0.9632575	total: 1.02s	remaining: 11.7s
# 8:	learn: 0.9544570	total: 1.16s	remaining: 11.7s
# 9:	learn: 0.9463631	total: 1.3s	remaining: 11.7s
# 10:	learn: 0.9387472	total: 1.46s	remaining: 11.8s
# 11:	learn: 0.9326498	total: 1.62s	remaining: 11.9s
# 12:	learn: 0.9296622	total: 1.76s	remaining: 11.8s
# 13:	learn: 0.9231583	total: 1.91s	remaining: 11.7s
# 14:	learn: 0.9177582	total: 2.06s	remaining: 11.7s
# 15:	learn: 0.9177337	total: 2.1s	remaining: 11s
# 16:	learn: 0.9152468	total: 2.25s	remaining: 11s
# 17:	learn: 0.9107840	total: 2.4s	remaining: 11s
# 18:	learn: 0.9084348	total: 2.54s	remaining: 10.8s
# 19:	learn: 0.9060539	total: 2.69s	remaining: 10.8s
# 20:	learn: 0.9044340	total: 2.84s	remaining: 10.7s
# 21:	learn: 0.9022258	total: 2.97s	remaining: 10.5s
# 22:	learn: 0.9003391	total: 3.13s	remaining: 10.5s
# 371:	learn: 0.9218350	total: 43.2s	remaining: 1m 12s
# 372:	learn: 0.9218311	total: 43.4s	remaining: 1m 12s
# 373:	learn: 0.9218310	total: 43.4s	remaining: 1m 12s
# 374:	learn: 0.9218295	total: 43.6s	remaining: 1m 12s
# 375:	learn: 0.9217980	total: 43.7s	remaining: 1m 12s
# 376:	learn: 0.9217953	total: 43.9s	remaining: 1m 12s
# 377:	learn: 0.9217954	total: 43.9s	remaining: 1m 12s
# 378:	learn: 0.9217947	total: 44.1s	remaining: 1m 12s
# 379:	learn: 0.9217946	total: 44.1s	remaining: 1m 11s
# 380:	learn: 0.9217945	total: 44.3s	remaining: 1m 11s
# 381:	learn: 0.9217937	total: 44.3s	remaining: 1m 11s
# 382:	learn: 0.9217932	total: 44.5s	remaining: 1m 11s
# 383:	learn: 0.9217926	total: 44.6s	remaining: 1m 11s
# 384:	learn: 0.9217919	total: 44.8s	remaining: 1m 11s
# 385:	learn: 0.9217555	total: 44.8s	remaining: 1m 11s
# 386:	learn: 0.9217527	total: 45s	remaining: 1m 11s
# 387:	learn: 0.9217516	total: 45s	remaining: 1m 11s
# 388:	learn: 0.9217506	total: 45.2s	remaining: 1m 11s
# 389:	learn: 0.9217496	total: 45.3s	remaining: 1m 10s
# 390:	learn: 0.9217491	total: 45.4s	remaining: 1m 10s
# 391:	learn: 0.9216267	total: 45.6s	remaining: 1m 10s
# 392:	learn: 0.9215948	total: 45.7s	remaining: 1m 10s
# 393:	learn: 0.9215947	total: 45.8s	remaining: 1m 10s
# 394:	learn: 0.9215921	total: 46s	remaining: 1m 10s
# 395:	learn: 0.9214053	total: 46s	remaining: 1m 10s
# 396:	learn: 0.9214034	total: 46.2s	remaining: 1m 10s
# 397:	learn: 0.9213933	total: 46.3s	remaining: 1m 10s
# 398:	learn: 0.9213914	total: 46.5s	remaining: 1m 9s
# 399:	learn: 0.9213909	total: 46.5s	remaining: 1m 9s
# 400:	learn: 0.9213872	total: 46.7s	remaining: 1m 9s
# 401:	learn: 0.9213762	total: 46.7s	remaining: 1m 9s
# 402:	learn: 0.9213748	total: 46.9s	remaining: 1m 9s
# 403:	learn: 0.9213592	total: 47s	remaining: 1m 9s
# 404:	learn: 0.9213586	total: 47.2s	remaining: 1m 9s
# 405:	learn: 0.9213585	total: 47.2s	remaining: 1m 9s
# 406:	learn: 0.9213579	total: 47.4s	remaining: 1m 9s
# 407:	learn: 0.9213539	total: 47.5s	remaining: 1m 8s
# 408:	learn: 0.9213535	total: 47.6s	remaining: 1m 8s
# 409:	learn: 0.9213535	total: 47.7s	remaining: 1m 8s
# 410:	learn: 0.9213527	total: 47.9s	remaining: 1m 8s
# 411:	learn: 0.9213503	total: 47.9s	remaining: 1m 8s
# 412:	learn: 0.9213494	total: 48.1s	remaining: 1m 8s
# 413:	learn: 0.9213340	total: 48.1s	remaining: 1m 8s
# 414:	learn: 0.9213339	total: 48.3s	remaining: 1m 8s
# 415:	learn: 0.9213146	total: 48.4s	remaining: 1m 7s
# 416:	learn: 0.9213138	total: 48.6s	remaining: 1m 7s
# 417:	learn: 0.9213116	total: 48.7s	remaining: 1m 7s
# 418:	learn: 0.9213111	total: 48.8s	remaining: 1m 7s
# 419:	learn: 0.9213025	total: 48.9s	remaining: 1m 7s
# 420:	learn: 0.9212999	total: 49.1s	remaining: 1m 7s
# 421:	learn: 0.9212066	total: 49.2s	remaining: 1m 7s
# 422:	learn: 0.9212050	total: 49.4s	remaining: 1m 7s
# 423:	learn: 0.9211907	total: 49.4s	remaining: 1m 7s
# 424:	learn: 0.9211903	total: 49.6s	remaining: 1m 7s
# 425:	learn: 0.9211870	total: 49.7s	remaining: 1m 6s
# 426:	learn: 0.9211860	total: 49.8s	remaining: 1m 6s
# 427:	learn: 0.9211690	total: 49.9s	remaining: 1m 6s
# 428:	learn: 0.9211676	total: 50.1s	remaining: 1m 6s
# 429:	learn: 0.9211390	total: 50.1s	remaining: 1m 6s
# 430:	learn: 0.9211373	total: 50.3s	remaining: 1m 6s
# 431:	learn: 0.9211202	total: 50.4s	remaining: 1m 6s
# 432:	learn: 0.9211196	total: 50.6s	remaining: 1m 6s
# 433:	learn: 0.9211195	total: 50.6s	remaining: 1m 5s
# 434:	learn: 0.9211182	total: 50.8s	remaining: 1m 5s
# 435:	learn: 0.9210927	total: 50.9s	remaining: 1m 5s
# 436:	learn: 0.9210916	total: 51s	remaining: 1m 5s
# 437:	learn: 0.9210857	total: 51.1s	remaining: 1m 5s
# 438:	learn: 0.9210852	total: 51.3s	remaining: 1m 5s
# 439:	learn: 0.9210851	total: 51.3s	remaining: 1m 5s
# 440:	learn: 0.9210836	total: 51.5s	remaining: 1m 5s
# 441:	learn: 0.9210826	total: 51.5s	remaining: 1m 5s
# 442:	learn: 0.9210820	total: 51.7s	remaining: 1m 5s
# 443:	learn: 0.9210674	total: 51.8s	remaining: 1m 4s
# 444:	learn: 0.9210664	total: 52s	remaining: 1m 4s
# 445:	learn: 0.9210526	total: 52s	remaining: 1m 4s
# 446:	learn: 0.9210515	total: 52.2s	remaining: 1m 4s
# 447:	learn: 0.9209999	total: 52.3s	remaining: 1m 4s
# 448:	learn: 0.9209987	total: 52.5s	remaining: 1m 4s
# 449:	learn: 0.9209987	total: 52.5s	remaining: 1m 4s
# 450:	learn: 0.9209975	total: 52.7s	remaining: 1m 4s
# 451:	learn: 0.9209970	total: 52.8s	remaining: 1m 3s
# 452:	learn: 0.9209970	total: 52.9s	remaining: 1m 3s
# 453:	learn: 0.9209929	total: 53s	remaining: 1m 3s
# 454:	learn: 0.9209925	total: 53.2s	remaining: 1m 3s
# 455:	learn: 0.9209906	total: 53.2s	remaining: 1m 3s
# 456:	learn: 0.9209906	total: 53.4s	remaining: 1m 3s
# 457:	learn: 0.9209897	total: 53.5s	remaining: 1m 3s
# 458:	learn: 0.9209891	total: 53.6s	remaining: 1m 3s
# 459:	learn: 0.9209891	total: 53.7s	remaining: 1m 3s
# 964:	learn: 0.9863396	total: 2m 4s	remaining: 4.52s
# 965:	learn: 0.9863351	total: 2m 4s	remaining: 4.39s
# 966:	learn: 0.9863314	total: 2m 5s	remaining: 4.27s
# 967:	learn: 0.9863278	total: 2m 5s	remaining: 4.14s
# 968:	learn: 0.9862433	total: 2m 5s	remaining: 4.01s
# 969:	learn: 0.9862343	total: 2m 5s	remaining: 3.88s
# 970:	learn: 0.9861972	total: 2m 5s	remaining: 3.75s
# 971:	learn: 0.9861417	total: 2m 5s	remaining: 3.62s
# 972:	learn: 0.9860275	total: 2m 5s	remaining: 3.49s
# 973:	learn: 0.9859901	total: 2m 6s	remaining: 3.37s
# 974:	learn: 0.9859331	total: 2m 6s	remaining: 3.24s
# 975:	learn: 0.9859248	total: 2m 6s	remaining: 3.11s
# 976:	learn: 0.9858877	total: 2m 6s	remaining: 2.98s
# 977:	learn: 0.9858491	total: 2m 6s	remaining: 2.85s
# 978:	learn: 0.9858491	total: 2m 6s	remaining: 2.72s
# 979:	learn: 0.9857959	total: 2m 6s	remaining: 2.59s
# 980:	learn: 0.9857629	total: 2m 7s	remaining: 2.46s
# 981:	learn: 0.9856386	total: 2m 7s	remaining: 2.33s
# 982:	learn: 0.9855742	total: 2m 7s	remaining: 2.2s
# 983:	learn: 0.9855745	total: 2m 7s	remaining: 2.07s
# 984:	learn: 0.9855631	total: 2m 7s	remaining: 1.94s
# 985:	learn: 0.9855515	total: 2m 7s	remaining: 1.81s
# 986:	learn: 0.9855081	total: 2m 7s	remaining: 1.68s
# 987:	learn: 0.9854377	total: 2m 7s	remaining: 1.55s
# 988:	learn: 0.9854141	total: 2m 8s	remaining: 1.42s
# 989:	learn: 0.9853831	total: 2m 8s	remaining: 1.29s
# 990:	learn: 0.9853564	total: 2m 8s	remaining: 1.17s
# 991:	learn: 0.9852987	total: 2m 8s	remaining: 1.04s
# 992:	learn: 0.9852622	total: 2m 8s	remaining: 907ms
# 993:	learn: 0.9852604	total: 2m 8s	remaining: 777ms
# 994:	learn: 0.9851794	total: 2m 8s	remaining: 648ms
# 995:	learn: 0.9851797	total: 2m 9s	remaining: 518ms
# 996:	learn: 0.9851717	total: 2m 9s	remaining: 389ms
# 997:	learn: 0.9851720	total: 2m 9s	remaining: 259ms
# 998:	learn: 0.9851687	total: 2m 9s	remaining: 129ms
# 999:	learn: 0.9851632	total: 2m 9s	remaining: 0us

# %% [markdown]
# Public LB performance:
#
# |Feature set / subset | sel9 | sel16 | sel25 |
# |---|---|---|---|
# |allfeat| 1.04071 | 1.00703 | 1.00865 |
# |basic| 1.32035 | 1.04198 | 1.041678 |
# |basicv2| 0.998474 | 1.023006 | 0.999249 |
# |text|
# |within|
# | mean fusion (3 best) | ? | ? | 0.982447 |

# %%
subm = ['submission-catboost-bestparams-features_{}_combination_sel25.csv'.format(id) for id in ['allfeat','basic','basicv2']]
average_submissions(subm,'sel25_3best_bestparams')
# Out:
# (214200,)
# (214200,)
# (214200,)
